# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Noteback on IBM Watson Studio

# %% [markdown]
# __Cavin__

# %% [markdown]
# _I am interested in Data Science because I enjoy statistics and coding, and the ability to tell stories from the vast amount of available data excites me_

# %% [markdown]
# ### Addition

# %%
1+1
# Out:
# 2

# %% [markdown]
# |Col_1 | Col_2 | Col_3 |
# |---|---|---|
# | Blue | Red| Green |
# | Fish | Lava | Grass |
#
# 1. Blue
# 2. Red
# 3. Green
#
# - Blue
# - Red
# - Green
# ![image.png](attachment:d83a1009-9d60-4908-b584-172ed4bd3259.png)
